# %%
import numpy as np
import pandas as pd
import os

import networkx as nx 
from matplotlib import pyplot as plt

# %%
import numpy as np

import pandas as pd
import os

import networkx as nx 
from matplotlib import pyplot as plt

from cart import DecisionTreeRegressor


from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
df_a=pd.DataFrame(data=housing['data'], columns=housing['feature_names'])
df_a['target']=housing['target']
df_a

list_feature_cols=df_a.columns.tolist()
list_feature_cols=[jcol for jcol in list_feature_cols if jcol not in ['target'] ]
print('features=', list_feature_cols)
target_col='target'

itrain0=np.int64(df_a.shape[0]*0.7)
print('int=', itrain0)
df_train=df_a[:itrain0]
df_val=df_a[itrain0:]
dtr0=DecisionTreeRegressor(node_level_max=3);
df_summary=dtr0.optimize(df_input=df_train.copy(), list_feature_cols=list_feature_cols, target_col=target_col)
# print('summary=\n', df_summary )
df_res=dtr0.infer(df_infer=df_val.copy(), list_feature_cols=list_feature_cols, target_col=target_col)
# Out:
# features= ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# int= 14447
# DecisionTreeRegressor class used
# node_level= 0
# node_level= 1
# node_level= 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-106b12b41045> in <module>
#      28 df_summary=dtr0.optimize(df_input=df_train.copy(), list_feature_cols=list_feature_cols, target_col=target_col)
#      29 # print('summary=\n', df_summary )
# ---> 30 df_res=dtr0.infer(df_infer=df_val.copy(), list_feature_cols=list_feature_cols, target_col=target_col)
#      31
#
# TypeError: infer() got an unexpected keyword argument 'df_infer'

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
# housing

# %%
os.getcwd()
# Out:
# '/Users/lunal.brown/Personal/DataScience/github/decision_tree_easy'

# %%
print(housing['frame'])
print('feature names=', housing['feature_names'])
housing.keys()
# Out:
# None
# feature names= ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
housing['target']
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
df_a=pd.DataFrame(data=housing['data'], columns=housing['feature_names'])
df_a['target']=housing['target']
df_a
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# 0        -122.23   4.526
# 1        -122.22   3.585
# 2        -122.24   3.521
# 3        -122.25   3.413
# 4        -122.25   3.422
# ...          ...     ...
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894
#
# [20640 rows x 9 columns]

# %%
from cart import DecisionTreeRegressor

# %%
list_feature_cols=df_a.columns.tolist()
list_feature_cols=[jcol for jcol in list_feature_cols if jcol not in ['target'] ]
print('features=', list_feature_cols)
target_col='target'

itrain0=np.int64(df_a.shape[0]*0.7)
print('int=', itrain0)
df_train=df_a[:itrain0]
df_val=df_a[itrain0:]
dtr0=DecisionTreeRegressor(node_level_max=3);
df_summary=dtr0.optimize(df_input=df_train.copy(), list_feature_cols=list_feature_cols, target_col=target_col)
print('summary=\n', df_summary )
# Out:
# features= ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# int= 14447
# DecisionTreeRegressor class used
# node_level= 0
# node_level= 1
# node_level= 2
# summary=
#    node_id  node_level   feature  threshold  information_gain  n_left  n_right  \
# 0    root           0    MedInc   5.028660          0.209066   11557     2890
# 1    1_0l           1    MedInc   2.733540          0.069132    4623     6934
# 2    1_0r           1    MedInc   6.433980          0.174253    1734     1156
# 3    2_0l           2  AveRooms   4.119548          0.054048    1849     2774
# 4    2_0r           2  AveOccup   2.313731          0.099527    1387     5547
# 5    2_1l           2  AveOccup   2.716868          0.103482     694     1040
# 6    2_1r           2    MedInc   8.023900          0.121448     693      463
#
#                                              df_left  \
# 0         MedInc  HouseAge  AveRooms  AveBedrms  ...
# 1        MedInc  HouseAge  AveRooms  AveBedrms  P...
# 2        MedInc  HouseAge  AveRooms  AveBedrms  P...
# 3        MedInc  HouseAge  AveRooms  AveBedrms  P...
# 4        MedInc  HouseAge  AveRooms  AveBedrms  P...
# 5       MedInc  HouseAge  AveRooms  AveBedrms  Po...
# 6       MedInc  HouseAge  AveRooms  AveBedrms  Po...
#
#                                             df_right parent_node_id
# 0        MedInc  HouseAge  AveRooms  AveBedrms  P...            n/a
# 1        MedInc  HouseAge  AveRooms  AveBedrms  P...           root
# 2        MedInc  HouseAge  AveRooms  AveBedrms  P...           root
# 3        MedInc  HouseAge  AveRooms  AveBedrms  P...           1_0l
# 4        MedInc  HouseAge  AveRooms  AveBedrms  P...           1_0l
# 5        MedInc  HouseAge  AveRooms  AveBedrms  P...           1_0r
# 6        MedInc  HouseAge  AveRooms  AveBedrms  P...           1_0r

# %%
# df_summary.at[0, 'df_left']
df_summary.columns.tolist()
# Out:
# ['node_id',
#  'node_level',
#  'feature',
#  'threshold',
#  'information_gain',
#  'n_left',
#  'n_right',
#  'df_left',
#  'df_right',
#  'parent_node_id']

# %%
df_summary.at[0, 'node_id']
# Out:
# 'root'

# %%
def get_nodes(df_p, df_grid):
    df_agg=pd.DataFrame([])
    for jlist in df_grid.values:
        jfeat=jlist[0] # 'hour'
        feat_threshold=jlist[1] # 8
        #
        cost_p=df_p[target_col].std(ddof=0) # parentノードのコスト
        n_sample_p=df_p.shape[0]
        #
        df_left=df_p[df_p[jfeat]<feat_threshold].reset_index(drop=True)
        cost_l=df_left[target_col].std(ddof=0)
        n_sample_l=df_left.shape[0]
        #
        df_right=df_p[df_p[jfeat]>=feat_threshold].reset_index(drop=True)
        cost_r=df_right[target_col].std(ddof=0)
        n_sample_r=df_right.shape[0]
        #
        information_gain=cost_p - (n_sample_l * cost_l / n_sample_p) - (n_sample_r * cost_r / n_sample_p)
        # print('feat={}, {:.2f}, {:.3f}, {:.3f}, {:.3f}, {:.4f}'.format( jfeat, feat_threshold, cost_p, cost_l, cost_r, information_gain) )
        df_j=pd.DataFrame({'feature':[jfeat], 'threshold':[feat_threshold], 'information_gain':[information_gain], 'df_left':[df_left], 'df_right':[df_right]})
        df_agg=pd.concat([df_agg, df_j],axis=0)
        del(df_left)
        del(df_right)
    #
    df_agg=df_agg.sort_values(by=['information_gain'],ascending=[False]*1).reset_index(drop=True)
    return df_agg.values.tolist()[0]

# %%
df_w=pd.DataFrame([])
df_w=pd.read_csv('weather_data_HanedaJan23rd2022.csv', header=0, encoding='cp932')
df_w.columns=np.arange(0, df_w.shape[1], 1)
df_w=df_w[[0,1,2,3,4,5,6]]
df_w=df_w[5:].reset_index(drop=True)
df_w=df_w.rename(columns={0:'datetime', 1:'temperature', 2:'high', 3:'low', 4:'wind', 5:'quolity', 6:'direction'})
df_w['datetime']=pd.to_datetime(df_w['datetime'], format='%Y/%m/%d %H:%M')
df_w['hour']=df_w['datetime'].dt.hour

list_feature_cols=['hour', 'wind']
target_col='temperature'
for jcol in list_feature_cols + [target_col]:
    df_w[jcol]=df_w[jcol].fillna(value=0).astype(np.float64)
df_w[:5]
# Out:
#              datetime  temperature high low  wind quolity direction  hour
# 0 2022-01-14 01:00:00          3.9    8   1   7.2       8        北西   1.0
# 1 2022-01-14 02:00:00          2.4    8   1   5.5       8        北西   2.0
# 2 2022-01-14 03:00:00          2.2    8   1   7.5       8        北西   3.0
# 3 2022-01-14 04:00:00          2.6    8   1   6.8       8       北北西   4.0
# 4 2022-01-14 05:00:00          2.8    8   1   8.7       8       北北西   5.0

# %%
def search_thresholds(df_p, list_feature_cols, n_quantiles=6):
    df_grid=pd.DataFrame([])
    df_quantile=df_p[list_feature_cols].quantile(q=np.linspace(0, 1, n_quantiles).tolist()[1:-1] ).reset_index().reset_index(drop=True).rename(columns={'index':'quantile'})
    # print('quantile=\n', df_quantile)
    for jcol in list_feature_cols:
        df_j=df_quantile[[jcol]].reset_index(drop=True)
        df_j['feature']=jcol
        df_j=df_j.rename(columns={jcol:'value'} )
        df_grid=pd.concat([df_grid, df_j],axis=0)
        del(df_j)
    df_grid=df_grid.reset_index(drop=True)
    df_grid=df_grid[['feature', 'value']]
    return df_grid

# %%
# ノードを追加していく
node_level_max=3

df_w0=df_w.copy()
n_quantiles=5

df_summary=pd.DataFrame([])
for node_level in np.arange(0,node_level_max,1):
    print('node_level=', node_level)
    if node_level==0:
        df_grid=search_thresholds(df_p=df_w0.copy(), list_feature_cols=list_feature_cols, n_quantiles=n_quantiles)
        jfeat, feat_threshold, information_gain, df_left, df_right=get_nodes(df_p=df_w0.copy(), df_grid=df_grid.copy() )
        if df_left.shape[0] + df_right.shape[0]!=df_w0.shape[0]:
            print('Error! {}, {}, n_sample={} '.format(df_left.shape[0], df_right.shape[0], df_w0.shape[0]) )
            raise ValueError;
        df_node_agg=pd.DataFrame({'node_id':[ str(node_level) + '_0' ], 'node_level':[node_level], 'feature':[jfeat], 'threshold':[feat_threshold], 
                              'information_gain':[information_gain], 'n_left':[df_left.shape[0]], 'n_right':[df_right.shape[0] ], 
                                  'df_left':[df_left], 'df_right':[df_right], 'parent_node_id':["n/a"] } )
        del(jfeat)
        del(feat_threshold)
        del(information_gain)
        del(df_left)
        del(df_right)
    elif node_level>=1:
        df_node_parent=df_summary[df_summary['node_level']==node_level-1].reset_index(drop=True)
        df_node_agg=pd.DataFrame([])
        for jdx, jrow in enumerate(df_node_parent.itertuples()):
            # print('**')
            df_left_parent=jrow.df_left
            # print('left parent type=', type(df_left_parent))
            df_grid=search_thresholds(df_p=df_left_parent.copy(), list_feature_cols=list_feature_cols, n_quantiles=n_quantiles)
            jfeat, feat_threshold, information_gain, df_left, df_right=get_nodes(df_p=df_left_parent.copy(), df_grid=df_grid.copy() )
            if df_left.shape[0] + df_right.shape[0]!=df_left_parent.shape[0]:
                print('Error! {}, {}, left parent n_sample={} '.format(df_left.shape[0], df_right.shape[0], df_left_parent.shape[0]) )
                raise ValueError;
            df_jl=pd.DataFrame({'node_id':[ str(node_level) + '_' + str(jdx) + 'l' ], 'node_level':[node_level], 'feature':[jfeat], 'threshold':[feat_threshold], 
                              'information_gain':[information_gain], 'n_left':[df_left.shape[0]], 'n_right':[df_right.shape[0] ], 
                                'df_left':[df_left], 'df_right':[df_right], 'parent_node_id':[jrow.node_id]})
            df_node_agg=pd.concat([df_node_agg, df_jl],axis=0)
            del(df_jl)
            del(df_left_parent)
            # 
            df_right_parent=jrow.df_right
            df_grid=search_thresholds(df_p=df_right_parent.copy(), list_feature_cols=list_feature_cols, n_quantiles=n_quantiles)
            jfeat, feat_threshold, information_gain, df_left, df_right=get_nodes(df_p=df_right_parent.copy(), df_grid=df_grid.copy() )
            if df_left.shape[0] + df_right.shape[0]!=df_right_parent.shape[0]:
                print('Error! {}, {}, right parent n_sample={} '.format(df_left.shape[0], df_right.shape[0], df_right_parent.shape[0]) )
                raise ValueError;
            df_jr=pd.DataFrame({'node_id':[ str(node_level) + '_' + str(jdx) + 'r' ], 'node_level':[node_level], 'feature':[jfeat], 'threshold':[feat_threshold], 
                              'information_gain':[information_gain], 'n_left':[df_left.shape[0]], 'n_right':[df_right.shape[0] ], 
                                'df_left':[df_left], 'df_right':[df_right], 'parent_node_id':[jrow.node_id]})
            df_node_agg=pd.concat([df_node_agg, df_jr],axis=0)
            del(df_jr)
            del(df_right_parent)
        del(df_node_parent)
        df_node_agg=df_node_agg.reset_index(drop=True)
    else:
        print('Error! node_level=', node_level)
        raise ValueError
    df_summary=pd.concat([df_summary, df_node_agg],axis=0).reset_index(drop=True)
    del(df_node_agg)
# Out:
# node_level= 0
# node_level= 1
# **
# left parent type= <class 'pandas.core.frame.DataFrame'>
# node_level= 2
# **
# left parent type= <class 'pandas.core.frame.DataFrame'>
# **
# left parent type= <class 'pandas.core.frame.DataFrame'>

# %%
df_summary
# Out:
#   node_id  node_level feature  threshold  information_gain  n_left  n_right  \
# 0     0_0           0    hour     11.500          0.471813     108      108
# 1    1_0l           1    hour      8.250          0.483131      81       27
# 2    1_0r           1    hour     17.500          0.276642      54       54
# 3    2_0l           2    hour      4.000          0.054358      36       45
# 4    2_0r           2    hour     10.000          0.156982       9       18
# 5    2_1l           2    wind      8.125          0.119092      40       14
# 6    2_1r           2    wind      5.800          0.239316      26       28
#
#                                              df_left  \
# 0                 datetime  temperature high low ...
# 1                datetime  temperature high low  ...
# 2                datetime  temperature high low  ...
# 3                datetime  temperature high low  ...
# 4               datetime  temperature high low  w...
# 5                datetime  temperature high low  ...
# 6                datetime  temperature high low  ...
#
#                                             df_right parent_node_id
# 0                 datetime  temperature high low ...            NaN
# 1                datetime  temperature high low  ...            0_0
# 2                datetime  temperature high low  ...            0_0
# 3                datetime  temperature high low  ...           1_0l
# 4                datetime  temperature high low  ...           1_0l
# 5                datetime  temperature high low  ...           1_0r
# 6                datetime  temperature high low  ...           1_0r

# %%
G = nx.Graph()
G.add_edge(1, 2, color="red")
G.add_edge(2, 3, color="red")
G.add_node(3)
G.add_node(4)
G.add_node(5)

A = nx.nx_agraph.to_agraph(G)  # convert to a graphviz graph
A.draw("attributes.png", prog="neato")  # Draw with pygraphviz

# convert back to networkx Graph with attributes on edges and
# default attributes as dictionary data
X = nx.nx_agraph.from_agraph(A)
# plt.show()
#print("edges")
#print(list(X.edges(data=True)))
print("default graph attributes")
print(X.graph)
print("node node attributes")
print(X.nodes.data(True))
# Out:
# default graph attributes
# {'graph': {}, 'node': {}, 'edge': {'color': ''}}
# node node attributes
# [('1', {}), ('2', {}), ('3', {}), ('4', {}), ('5', {})]

# %%
# nx.draw(G)
nx.draw(X)
plt.show()

# %%
DG = nx.DiGraph()
DG.add_weighted_edges_from([(1, 2, 0.5), (4, 1, 0.9)])
DG.out_degree(1, weight='weight')
# 0.5
DG.degree(1, weight='weight')
nx.draw(DG)
A = nx.nx_agraph.to_agraph(DG)  # convert to a graphviz graph
A.draw("attributes.png", prog="neato")  # Draw with pygraphviz

# %%
get_nodes(df_p=df_w.copy(), df_grid=df_grid.copy())
# Out:
# ['hour',
#  9.0,
#  0.6931166439341212,
#                datetime  temperature high low  wind quolity direction  hour
#  0  2022-01-14 01:00:00          3.9    8   1   7.2       8        北西   1.0
#  1  2022-01-14 02:00:00          2.4    8   1   5.5       8        北西   2.0
#  2  2022-01-14 03:00:00          2.2    8   1   7.5       8        北西   3.0
#  3  2022-01-14 04:00:00          2.6    8   1   6.8       8       北北西   4.0
#  4  2022-01-14 05:00:00          2.8    8   1   8.7       8       北北西   5.0
#  ..                 ...          ...  ...  ..   ...     ...       ...   ...
#  76 2022-01-22 05:00:00          3.1    8   1   6.6       8        北西   5.0
#  77 2022-01-22 06:00:00          2.9    8   1   7.0       8       北北西   6.0
#  78 2022-01-22 07:00:00          2.9    8   1   6.6       8        北西   7.0
#  79 2022-01-22 08:00:00          3.7    8   1   5.4       8        北西   8.0
#  80 2022-01-23 00:00:00          5.9    8   1   3.1       8       北北西   0.0
#
#  [81 rows x 8 columns],
#                 datetime  temperature high low  wind quolity direction  hour
#  0   2022-01-14 09:00:00          4.2    8   1   2.9       8        北西   9.0
#  1   2022-01-14 10:00:00          5.5    8   1   3.5       8       西北西  10.0
#  2   2022-01-14 11:00:00          7.0    8   1   4.3       8        北西  11.0
#  3   2022-01-14 12:00:00          7.6    8   1   4.0       8       西北西  12.0
#  4   2022-01-14 13:00:00          8.8    8   1   5.8       8         西  13.0
#  ..                  ...          ...  ...  ..   ...     ...       ...   ...
#  130 2022-01-22 19:00:00          7.3    8   1   1.0       8        南東  19.0
#  131 2022-01-22 20:00:00          7.8    8   1   0.5       8       東南東  20.0
#  132 2022-01-22 21:00:00          7.5    8   1   4.2       8       東北東  21.0
#  133 2022-01-22 22:00:00          6.9    8   1   3.5       8        北東  22.0
#  134 2022-01-22 23:00:00          6.8    8   1   3.5       8         北  23.0
#
#  [135 rows x 8 columns]]

# %%
# df_w[:17]
df_w[df_w[jfeat]>feat_threshold][target_col]
del(ym)

# %%
df_w.dtypes
list_feature_cols
# Out:
# ['hour', 'wind']

# %%
train_X=df_w.values
train_X
# Out:
# array([[Timestamp('2022-01-14 01:00:00'), 3.9, '8', ..., '8', '北西', 1.0],
#        [Timestamp('2022-01-14 02:00:00'), 2.4, '8', ..., '8', '北西', 2.0],
#        [Timestamp('2022-01-14 03:00:00'), 2.2, '8', ..., '8', '北西', 3.0],
#        ...,
#        [Timestamp('2022-01-22 22:00:00'), 6.9, '8', ..., '8', '北東', 22.0],
#        [Timestamp('2022-01-22 23:00:00'), 6.8, '8', ..., '8', '北', 23.0],
#        [Timestamp('2022-01-23 00:00:00'), 5.9, '8', ..., '8', '北北西', 0.0]],
#       dtype=object)

# %%
#for jrow in train_X:
#    print(jrow[0], jrow[1], jrow[2], jrow[3])
for l0 in df_w.values:
    print(l0)
# Out:
# [Timestamp('2022-01-14 01:00:00') 3.9 '8' '1' 7.2 '8' '北西' 1.0]
# [Timestamp('2022-01-14 02:00:00') 2.4 '8' '1' 5.5 '8' '北西' 2.0]
# [Timestamp('2022-01-14 03:00:00') 2.2 '8' '1' 7.5 '8' '北西' 3.0]
# [Timestamp('2022-01-14 04:00:00') 2.6 '8' '1' 6.8 '8' '北北西' 4.0]
# [Timestamp('2022-01-14 05:00:00') 2.8 '8' '1' 8.7 '8' '北北西' 5.0]
# [Timestamp('2022-01-14 06:00:00') 2.1 '8' '1' 5.3 '8' '北西' 6.0]
# [Timestamp('2022-01-14 07:00:00') 1.6 '8' '1' 5.0 '8' '北西' 7.0]
# [Timestamp('2022-01-14 08:00:00') 2.8 '8' '1' 4.8 '8' '北西' 8.0]
# [Timestamp('2022-01-14 09:00:00') 4.2 '8' '1' 2.9 '8' '北西' 9.0]
# [Timestamp('2022-01-14 10:00:00') 5.5 '8' '1' 3.5 '8' '西北西' 10.0]
# [Timestamp('2022-01-14 11:00:00') 7.0 '8' '1' 4.3 '8' '北西' 11.0]
# [Timestamp('2022-01-14 12:00:00') 7.6 '8' '1' 4.0 '8' '西北西' 12.0]
# [Timestamp('2022-01-14 13:00:00') 8.8 '8' '1' 5.8 '8' '西' 13.0]
# [Timestamp('2022-01-14 14:00:00') 8.6 '8' '1' 6.4 '8' '西北西' 14.0]
# [Timestamp('2022-01-14 15:00:00') 8.6 '8' '1' 8.3 '8' '北西' 15.0]
# [Timestamp('2022-01-14 16:00:00') 7.9 '8' '1' 8.5 '8' '北西' 16.0]
# [Timestamp('2022-01-14 17:00:00') 6.8 '8' '1' 8.4 '8' '北西' 17.0]
# [Timestamp('2022-01-14 18:00:00') 6.3 '8' '1' 9.7 '8' '北西' 18.0]
# [Timestamp('2022-01-14 19:00:00') 5.7 '8' '1' 10.1 '8' '北西' 19.0]
# [Timestamp('2022-01-14 20:00:00') 5.1 '8' '1' 10.8 '8' '北北西' 20.0]
# [Timestamp('2022-01-14 21:00:00') 5.1 '8' '1' 8.4 '8' '北西' 21.0]
# [Timestamp('2022-01-14 22:00:00') 5.2 '8' '1' 10.3 '8' '北北西' 22.0]
# [Timestamp('2022-01-14 23:00:00') 4.8 '8' '1' 8.7 '8' '北西' 23.0]
# [Timestamp('2022-01-15 00:00:00') 4.1 '8' '1' 5.5 '8' '北北西' 0.0]
# [Timestamp('2022-01-15 01:00:00') 3.6 '8' '1' 3.9 '8' '北西' 1.0]
# [Timestamp('2022-01-15 02:00:00') 3.2 '8' '1' 4.1 '8' '北西' 2.0]
# [Timestamp('2022-01-15 03:00:00') 2.9 '8' '1' 2.1 '8' '西北西' 3.0]
# [Timestamp('2022-01-15 04:00:00') 3.9 '8' '1' 2.7 '8' '北西' 4.0]
# [Timestamp('2022-01-15 05:00:00') 3.9 '8' '1' 3.5 '8' '北西' 5.0]
# [Timestamp('2022-01-15 06:00:00') 2.5 '8' '1' 3.0 '8' '北西' 6.0]
# [Timestamp('2022-01-15 07:00:00') 1.9 '8' '1' 5.2 '8' '北西' 7.0]
# [Timestamp('2022-01-15 08:00:00') 4.3 '8' '1' 7.2 '8' '西北西' 8.0]
# [Timestamp('2022-01-15 09:00:00') 7.2 '8' '1' 7.0 '8' '北北西' 9.0]
# [Timestamp('2022-01-15 10:00:00') 8.4 '8' '1' 5.7 '8' '西北西' 10.0]
# [Timestamp('2022-01-15 11:00:00') 9.6 '8' '1' 5.9 '8' '北西' 11.0]
# [Timestamp('2022-01-15 12:00:00') 9.6 '8' '1' 3.7 '8' '北北西' 12.0]
# [Timestamp('2022-01-15 13:00:00') 10.0 '8' '1' 4.3 '8' '北' 13.0]
# [Timestamp('2022-01-15 14:00:00') 9.7 '8' '1' 5.6 '8' '北' 14.0]
# [Timestamp('2022-01-15 15:00:00') 10.0 '8' '1' 3.3 '8' '北北西' 15.0]
# [Timestamp('2022-01-15 16:00:00') 8.6 '8' '1' 2.8 '8' '北北西' 16.0]
# [Timestamp('2022-01-15 17:00:00') 7.9 '8' '1' 3.6 '8' '北西' 17.0]
# [Timestamp('2022-01-15 18:00:00') 8.6 '8' '1' 5.4 '8' '北北東' 18.0]
# [Timestamp('2022-01-15 19:00:00') 8.5 '8' '1' 6.0 '8' '北' 19.0]
# [Timestamp('2022-01-15 20:00:00') 7.2 '8' '1' 4.8 '8' '北' 20.0]
# [Timestamp('2022-01-15 21:00:00') 7.2 '8' '1' 5.8 '8' '北北西' 21.0]
# [Timestamp('2022-01-15 22:00:00') 6.7 '8' '1' 6.0 '8' '北北西' 22.0]
# [Timestamp('2022-01-15 23:00:00') 5.4 '8' '1' 5.0 '8' '北北西' 23.0]
# [Timestamp('2022-01-16 00:00:00') 5.9 '8' '1' 5.8 '8' '北北西' 0.0]
# [Timestamp('2022-01-16 01:00:00') 5.8 '8' '1' 5.6 '8' '北' 1.0]
# [Timestamp('2022-01-16 02:00:00') 5.7 '8' '1' 4.8 '8' '北北西' 2.0]
# [Timestamp('2022-01-16 03:00:00') 5.7 '8' '1' 4.2 '8' '北' 3.0]
# [Timestamp('2022-01-16 04:00:00') 5.1 '8' '1' 4.4 '8' '北北東' 4.0]
# [Timestamp('2022-01-16 05:00:00') 4.6 '8' '1' 3.5 '8' '北北東' 5.0]
# [Timestamp('2022-01-16 06:00:00') 4.2 '8' '1' 4.6 '8' '北北東' 6.0]
# [Timestamp('2022-01-16 07:00:00') 3.8 '8' '1' 3.3 '8' '北' 7.0]
# [Timestamp('2022-01-16 08:00:00') 4.1 '8' '1' 1.9 '8' '北北西' 8.0]
# [Timestamp('2022-01-16 09:00:00') 5.1 '8' '1' 1.5 '8' '北北西' 9.0]
# [Timestamp('2022-01-16 10:00:00') 6.2 '8' '1' 1.7 '8' '北東' 10.0]
# [Timestamp('2022-01-16 11:00:00') 6.8 '8' '1' 2.6 '8' '東南東' 11.0]
# [Timestamp('2022-01-16 12:00:00') 7.4 '8' '1' 1.6 '8' '東北東' 12.0]
# [Timestamp('2022-01-16 13:00:00') 8.1 '8' '1' 2.3 '8' '東北東' 13.0]
# [Timestamp('2022-01-16 14:00:00') 11.2 '8' '1' 3.9 '8' '南南東' 14.0]
# [Timestamp('2022-01-16 15:00:00') 10.6 '8' '1' 5.0 '8' '南南東' 15.0]
# [Timestamp('2022-01-16 16:00:00') 10.6 '8' '1' 6.6 '8' '南西' 16.0]
# [Timestamp('2022-01-16 17:00:00') 9.0 '8' '1' 2.3 '8' '西' 17.0]
# [Timestamp('2022-01-16 18:00:00') 9.4 '8' '1' 0.8 '8' '東北東' 18.0]
# [Timestamp('2022-01-16 19:00:00') 9.4 '8' '1' 3.3 '8' '北北東' 19.0]
# [Timestamp('2022-01-16 20:00:00') 8.8 '8' '1' 4.3 '8' '北' 20.0]
# [Timestamp('2022-01-16 21:00:00') 7.9 '8' '1' 3.4 '8' '北' 21.0]
# [Timestamp('2022-01-16 22:00:00') 6.1 '8' '1' 2.4 '8' '北西' 22.0]
# [Timestamp('2022-01-16 23:00:00') 5.8 '8' '1' 3.2 '8' '西北西' 23.0]
# [Timestamp('2022-01-17 00:00:00') 5.3 '8' '1' 1.9 '8' '西' 0.0]
# [Timestamp('2022-01-17 01:00:00') 4.4 '8' '1' 2.3 '8' '西' 1.0]
# [Timestamp('2022-01-17 02:00:00') 4.6 '8' '1' 1.4 '8' '西' 2.0]
# [Timestamp('2022-01-17 03:00:00') 4.1 '8' '1' 1.6 '8' '西南西' 3.0]
# [Timestamp('2022-01-17 04:00:00') 3.1 '8' '1' 2.3 '8' '西' 4.0]
# [Timestamp('2022-01-17 05:00:00') 3.3 '8' '1' 1.9 '8' '西北西' 5.0]
# [Timestamp('2022-01-17 06:00:00') 3.1 '8' '1' 1.4 '8' '西南西' 6.0]
# [Timestamp('2022-01-17 07:00:00') 3.7 '8' '1' 0.7 '8' '北西' 7.0]
# [Timestamp('2022-01-17 08:00:00') 4.8 '8' '1' 3.1 '8' '西' 8.0]
# [Timestamp('2022-01-17 09:00:00') 7.3 '8' '1' 2.4 '8' '西北西' 9.0]
# [Timestamp('2022-01-17 10:00:00') 8.6 '8' '1' 2.3 '8' '北西' 10.0]
# [Timestamp('2022-01-17 11:00:00') 8.3 '8' '1' 1.9 '8' '東' 11.0]
# [Timestamp('2022-01-17 12:00:00') 8.7 '8' '1' 2.1 '8' '東' 12.0]
# [Timestamp('2022-01-17 13:00:00') 8.8 '8' '1' 2.8 '8' '東南東' 13.0]
# [Timestamp('2022-01-17 14:00:00') 9.1 '8' '1' 2.5 '8' '東' 14.0]
# [Timestamp('2022-01-17 15:00:00') 9.7 '8' '1' 4.0 '8' '北東' 15.0]
# [Timestamp('2022-01-17 16:00:00') 10.0 '8' '1' 2.8 '8' '北北東' 16.0]
# [Timestamp('2022-01-17 17:00:00') 10.1 '8' '1' 3.0 '8' '北北東' 17.0]
# [Timestamp('2022-01-17 18:00:00') 9.9 '8' '1' 4.4 '8' '東' 18.0]
# [Timestamp('2022-01-17 19:00:00') 8.8 '8' '1' 5.8 '8' '北' 19.0]
# [Timestamp('2022-01-17 20:00:00') 8.4 '8' '1' 5.9 '8' '北' 20.0]
# [Timestamp('2022-01-17 21:00:00') 8.2 '8' '1' 4.5 '8' '北' 21.0]
# [Timestamp('2022-01-17 22:00:00') 7.7 '8' '1' 3.9 '8' '北北東' 22.0]
# [Timestamp('2022-01-17 23:00:00') 5.2 '8' '1' 2.9 '8' '西北西' 23.0]
# [Timestamp('2022-01-18 00:00:00') 5.1 '8' '1' 4.0 '8' '西北西' 0.0]
# [Timestamp('2022-01-18 01:00:00') 4.8 '8' '1' 3.2 '8' '北西' 1.0]
# [Timestamp('2022-01-18 02:00:00') 6.6 '8' '1' 2.5 '8' '北北東' 2.0]
# [Timestamp('2022-01-18 03:00:00') 5.0 '8' '1' 9.0 '8' '北北西' 3.0]
# [Timestamp('2022-01-18 04:00:00') 4.6 '8' '1' 10.1 '8' '北北西' 4.0]
# [Timestamp('2022-01-18 05:00:00') 4.3 '8' '1' 10.9 '8' '北北西' 5.0]
# [Timestamp('2022-01-18 06:00:00') 4.0 '8' '1' 7.7 '8' '北北西' 6.0]
# [Timestamp('2022-01-18 07:00:00') 3.1 '8' '1' 6.6 '8' '北北西' 7.0]
# [Timestamp('2022-01-18 08:00:00') 4.8 '8' '1' 7.5 '8' '北北西' 8.0]
# [Timestamp('2022-01-18 09:00:00') 5.4 '8' '1' 7.0 '8' '北北西' 9.0]
# [Timestamp('2022-01-18 10:00:00') 6.3 '8' '1' 5.8 '8' '北' 10.0]
# [Timestamp('2022-01-18 11:00:00') 6.9 '8' '1' 3.3 '8' '北北東' 11.0]
# [Timestamp('2022-01-18 12:00:00') 6.9 '8' '1' 3.0 '8' '北北西' 12.0]
# [Timestamp('2022-01-18 13:00:00') 7.2 '8' '1' 2.4 '8' '北' 13.0]
# [Timestamp('2022-01-18 14:00:00') 7.2 '8' '1' 5.2 '8' '北' 14.0]
# [Timestamp('2022-01-18 15:00:00') 7.2 '8' '1' 7.9 '8' '北' 15.0]
# [Timestamp('2022-01-18 16:00:00') 6.7 '8' '1' 7.6 '8' '北北西' 16.0]
# [Timestamp('2022-01-18 17:00:00') 5.7 '8' '1' 8.9 '8' '北北西' 17.0]
# [Timestamp('2022-01-18 18:00:00') 5.2 '8' '1' 9.1 '8' '北北西' 18.0]
# [Timestamp('2022-01-18 19:00:00') 4.6 '8' '1' 9.8 '8' '北北西' 19.0]
# [Timestamp('2022-01-18 20:00:00') 4.3 '8' '1' 8.9 '8' '北北西' 20.0]
# [Timestamp('2022-01-18 21:00:00') 4.6 '8' '1' 11.5 '8' '北北西' 21.0]
# [Timestamp('2022-01-18 22:00:00') 3.7 '8' '1' 7.7 '8' '北北西' 22.0]
# [Timestamp('2022-01-18 23:00:00') 3.3 '8' '1' 6.7 '8' '北西' 23.0]
# [Timestamp('2022-01-19 00:00:00') 2.3 '8' '1' 5.6 '8' '北西' 0.0]
# [Timestamp('2022-01-19 01:00:00') 2.5 '8' '1' 5.5 '8' '北西' 1.0]
# [Timestamp('2022-01-19 02:00:00') 2.7 '8' '1' 5.9 '8' '北西' 2.0]
# [Timestamp('2022-01-19 03:00:00') 3.2 '8' '1' 8.5 '8' '北西' 3.0]
# [Timestamp('2022-01-19 04:00:00') 3.2 '8' '1' 7.7 '8' '北西' 4.0]
# [Timestamp('2022-01-19 05:00:00') 3.1 '8' '1' 7.2 '8' '北西' 5.0]
# [Timestamp('2022-01-19 06:00:00') 2.8 '8' '1' 6.7 '8' '北西' 6.0]
# [Timestamp('2022-01-19 07:00:00') 2.5 '8' '1' 5.4 '8' '北西' 7.0]
# [Timestamp('2022-01-19 08:00:00') 4.5 '8' '1' 6.4 '8' '北西' 8.0]
# [Timestamp('2022-01-19 09:00:00') 5.5 '8' '1' 6.8 '8' '北北西' 9.0]
# [Timestamp('2022-01-19 10:00:00') 6.0 '8' '1' 6.3 '8' '北' 10.0]
# [Timestamp('2022-01-19 11:00:00') 6.6 '8' '1' 4.1 '8' '北北東' 11.0]
# [Timestamp('2022-01-19 12:00:00') 6.8 '8' '1' 3.5 '8' '北東' 12.0]
# [Timestamp('2022-01-19 13:00:00') 6.7 '8' '1' 2.4 '8' '東南東' 13.0]
# [Timestamp('2022-01-19 14:00:00') 6.7 '8' '1' 2.6 '8' '東南東' 14.0]
# [Timestamp('2022-01-19 15:00:00') 6.7 '8' '1' 2.9 '8' '南東' 15.0]
# [Timestamp('2022-01-19 16:00:00') 6.8 '8' '1' 3.4 '8' '南南東' 16.0]
# [Timestamp('2022-01-19 17:00:00') 5.9 '8' '1' 3.2 '8' '南南東' 17.0]
# [Timestamp('2022-01-19 18:00:00') 6.2 '8' '1' 2.5 '8' '南' 18.0]
# [Timestamp('2022-01-19 19:00:00') 6.3 '8' '1' 2.1 '8' '南南東' 19.0]
# [Timestamp('2022-01-19 20:00:00') 5.9 '8' '1' 1.2 '8' '西南西' 20.0]
# [Timestamp('2022-01-19 21:00:00') 5.8 '8' '1' 1.3 '8' '北西' 21.0]
# [Timestamp('2022-01-19 22:00:00') 5.6 '8' '1' 0.8 '8' '南' 22.0]
# [Timestamp('2022-01-19 23:00:00') 4.2 '8' '1' 2.6 '8' '西北西' 23.0]
# [Timestamp('2022-01-20 00:00:00') 3.6 '8' '1' 3.1 '8' '北西' 0.0]
# [Timestamp('2022-01-20 01:00:00') 2.3 '8' '1' 2.2 '8' '西' 1.0]
# [Timestamp('2022-01-20 02:00:00') 1.5 '8' '1' 3.0 '8' '西北西' 2.0]
# [Timestamp('2022-01-20 03:00:00') 2.4 '8' '1' 2.2 '8' '西北西' 3.0]
# [Timestamp('2022-01-20 04:00:00') 2.1 '8' '1' 2.1 '8' '西北西' 4.0]
# [Timestamp('2022-01-20 05:00:00') 0.6 '8' '1' 3.3 '8' '西' 5.0]
# [Timestamp('2022-01-20 06:00:00') 0.3 '8' '1' 3.4 '8' '北北西' 6.0]
# [Timestamp('2022-01-20 07:00:00') 1.9 '8' '1' 2.4 '8' '北北東' 7.0]
# [Timestamp('2022-01-20 08:00:00') 2.6 '8' '1' 2.4 '8' '北' 8.0]
# [Timestamp('2022-01-20 09:00:00') 3.2 '8' '1' 2.4 '8' '北北東' 9.0]
# [Timestamp('2022-01-20 10:00:00') 4.4 '8' '1' 2.0 '8' '北' 10.0]
# [Timestamp('2022-01-20 11:00:00') 5.7 '8' '1' 2.0 '8' '北北東' 11.0]
# [Timestamp('2022-01-20 12:00:00') 6.7 '8' '1' 3.6 '8' '北北東' 12.0]
# [Timestamp('2022-01-20 13:00:00') 7.6 '8' '1' 5.2 '8' '北北西' 13.0]
# [Timestamp('2022-01-20 14:00:00') 7.9 '8' '1' 8.2 '8' '北' 14.0]
# [Timestamp('2022-01-20 15:00:00') 8.0 '8' '1' 8.2 '8' '北北西' 15.0]
# [Timestamp('2022-01-20 16:00:00') 7.7 '8' '1' 10.3 '8' '北北西' 16.0]
# [Timestamp('2022-01-20 17:00:00') 6.7 '8' '1' 8.8 '8' '北北西' 17.0]
# [Timestamp('2022-01-20 18:00:00') 6.0 '8' '1' 8.3 '8' '北北西' 18.0]
# [Timestamp('2022-01-20 19:00:00') 5.3 '8' '1' 9.2 '8' '北西' 19.0]
# [Timestamp('2022-01-20 20:00:00') 4.6 '8' '1' 9.7 '8' '北北西' 20.0]
# [Timestamp('2022-01-20 21:00:00') 3.8 '8' '1' 8.9 '8' '北北西' 21.0]
# [Timestamp('2022-01-20 22:00:00') 4.0 '8' '1' 10.0 '8' '北西' 22.0]
# [Timestamp('2022-01-20 23:00:00') 3.6 '8' '1' 7.9 '8' '北西' 23.0]
# [Timestamp('2022-01-21 00:00:00') 3.0 '8' '1' 9.7 '8' '北西' 0.0]
# [Timestamp('2022-01-21 01:00:00') 3.0 '8' '1' 9.0 '8' '北西' 1.0]
# [Timestamp('2022-01-21 02:00:00') 2.8 '8' '1' 7.6 '8' '北西' 2.0]
# [Timestamp('2022-01-21 03:00:00') 1.9 '8' '1' 5.9 '8' '北西' 3.0]
# [Timestamp('2022-01-21 04:00:00') 1.4 '8' '1' 4.9 '8' '北西' 4.0]
# [Timestamp('2022-01-21 05:00:00') 1.4 '8' '1' 5.0 '8' '北西' 5.0]
# [Timestamp('2022-01-21 06:00:00') 1.0 '8' '1' 3.5 '8' '北西' 6.0]
# [Timestamp('2022-01-21 07:00:00') 0.8 '8' '1' 3.9 '8' '北西' 7.0]
# [Timestamp('2022-01-21 08:00:00') 3.3 '8' '1' 6.3 '8' '北西' 8.0]
# [Timestamp('2022-01-21 09:00:00') 4.6 '8' '1' 6.7 '8' '北西' 9.0]
# [Timestamp('2022-01-21 10:00:00') 5.5 '8' '1' 7.8 '8' '北西' 10.0]
# [Timestamp('2022-01-21 11:00:00') 6.4 '8' '1' 7.8 '8' '北北西' 11.0]
# [Timestamp('2022-01-21 12:00:00') 6.7 '8' '1' 9.0 '8' '北北西' 12.0]
# [Timestamp('2022-01-21 13:00:00') 6.8 '8' '1' 11.4 '8' '北' 13.0]
# [Timestamp('2022-01-21 14:00:00') 6.8 '8' '1' 9.9 '8' '北' 14.0]
# [Timestamp('2022-01-21 15:00:00') 6.8 '8' '1' 10.3 '8' '北' 15.0]
# [Timestamp('2022-01-21 16:00:00') 6.1 '8' '1' 10.0 '8' '北北西' 16.0]
# [Timestamp('2022-01-21 17:00:00') 4.7 '8' '1' 8.6 '8' '北北西' 17.0]
# [Timestamp('2022-01-21 18:00:00') 4.2 '8' '1' 9.8 '8' '北北西' 18.0]
# [Timestamp('2022-01-21 19:00:00') 3.3 '8' '1' 8.9 '8' '北北西' 19.0]
# [Timestamp('2022-01-21 20:00:00') 2.9 '8' '1' 7.7 '8' '北北西' 20.0]
# [Timestamp('2022-01-21 21:00:00') 1.9 '8' '1' 5.3 '8' '北北西' 21.0]
# [Timestamp('2022-01-21 22:00:00') 2.7 '8' '1' 6.6 '8' '北北西' 22.0]
# [Timestamp('2022-01-21 23:00:00') 2.7 '8' '1' 7.0 '8' '北北西' 23.0]
# [Timestamp('2022-01-22 00:00:00') 2.5 '8' '1' 5.6 '8' '北西' 0.0]
# [Timestamp('2022-01-22 01:00:00') 3.2 '8' '1' 6.1 '8' '北北西' 1.0]
# [Timestamp('2022-01-22 02:00:00') 4.0 '8' '1' 7.4 '8' '北北西' 2.0]
# [Timestamp('2022-01-22 03:00:00') 3.1 '8' '1' 6.1 '8' '北西' 3.0]
# [Timestamp('2022-01-22 04:00:00') 2.9 '8' '1' 7.0 '8' '北西' 4.0]
# [Timestamp('2022-01-22 05:00:00') 3.1 '8' '1' 6.6 '8' '北西' 5.0]
# [Timestamp('2022-01-22 06:00:00') 2.9 '8' '1' 7.0 '8' '北北西' 6.0]
# [Timestamp('2022-01-22 07:00:00') 2.9 '8' '1' 6.6 '8' '北西' 7.0]
# [Timestamp('2022-01-22 08:00:00') 3.7 '8' '1' 5.4 '8' '北西' 8.0]
# [Timestamp('2022-01-22 09:00:00') 5.0 '8' '1' 4.6 '8' '北西' 9.0]
# [Timestamp('2022-01-22 10:00:00') 5.9 '8' '1' 2.4 '8' '東北東' 10.0]
# [Timestamp('2022-01-22 11:00:00') 5.7 '8' '1' 2.5 '8' '東北東' 11.0]
# [Timestamp('2022-01-22 12:00:00') 7.3 '8' '1' 1.7 '8' '東北東' 12.0]
# [Timestamp('2022-01-22 13:00:00') 7.4 '8' '1' 2.8 '8' '東' 13.0]
# [Timestamp('2022-01-22 14:00:00') 7.9 '8' '1' 3.4 '8' '南東' 14.0]
# [Timestamp('2022-01-22 15:00:00') 8.0 '8' '1' 3.3 '8' '南東' 15.0]
# [Timestamp('2022-01-22 16:00:00') 7.6 '8' '1' 2.6 '8' '南東' 16.0]
# [Timestamp('2022-01-22 17:00:00') 5.5 '8' '1' 2.2 '8' '南東' 17.0]
# [Timestamp('2022-01-22 18:00:00') 7.2 '8' '1' 1.5 '8' '東南東' 18.0]
# [Timestamp('2022-01-22 19:00:00') 7.3 '8' '1' 1.0 '8' '南東' 19.0]
# [Timestamp('2022-01-22 20:00:00') 7.8 '8' '1' 0.5 '8' '東南東' 20.0]
# [Timestamp('2022-01-22 21:00:00') 7.5 '8' '1' 4.2 '8' '東北東' 21.0]
# [Timestamp('2022-01-22 22:00:00') 6.9 '8' '1' 3.5 '8' '北東' 22.0]
# [Timestamp('2022-01-22 23:00:00') 6.8 '8' '1' 3.5 '8' '北' 23.0]
# [Timestamp('2022-01-23 00:00:00') 5.9 '8' '1' 3.1 '8' '北北西' 0.0]

# %%
df_w.dtypes
# Out:
# datetime       object
# temperature    object
# high           object
# low            object
# wind           object
# quolity        object
# direction      object
# dtype: object
